# %% [markdown]
# <a href="https://colab.research.google.com/github/s-rafia/Samsung-Innovation-Campus-AI-Training/blob/main/Pandas_csv_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# One way to mount using google drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
import pandas as pd

FilePath = "/content/data_Iris.csv"
df = pd.read_csv(FilePath)

df.head()

# %% [markdown]
# The way I mounted, by uploading the file in colab

# %%
df = pd.read_csv("/content/data_Iris.csv")

# %% [markdown]
# # **1. Data Viewing**

# %%
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.tail(1)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # **2. Selection**

# %%
df['Sepal.Length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Sepal.Length, Length: 150, dtype: float64

# %%
df[['Sepal.Length', 'Sepal.Width']]
# Out:
#      Sepal.Length  Sepal.Width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Sepal.Length       5.1
# Sepal.Width        3.5
# Petal.Length       1.4
# Petal.Width        0.2
# Species         setosa
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # **3. Conditional Filtering**

# %%
df[df['Species'] == "setosa"]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df[df['Sepal.Length'] > 5]
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [118 rows x 5 columns]

# %% [markdown]
# # **4. Data Manipulation**

# %% [markdown]
# Add New Column

# %%
df['Sepal.Area'] = df['Sepal.Length'] * df['Sepal.Width']
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_area  Sepal.Area
# 0         17.85       17.85
# 1         14.70       14.70
# 2         15.04       15.04
# ...

# %%
df['Petal.Size'] = df['Petal.Length'] + df['Petal.Width']
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_area  Sepal.Area  Petal.Size
# 0         17.85       17.85         1.6
# 1         14.70       14.70         1.6
# ...

# %% [markdown]
# Drop column

# %%
df.drop("Sepal.Area", axis=1)
# axis = 1 for column, axis = 0 for row
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_area  Petal.Size
# 0         17.85         1.6
# 1         14.70         1.6
# 2         15.04         1.5
# ...

# %%
df.drop("Petal.Size", axis=1)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_area  Sepal.Area
# 0         17.85       17.85
# 1         14.70       14.70
# 2         15.04       15.04
# ...

# %% [markdown]
# # If any column have missing values drop the entire row

# %%
df.dropna()
# Drops a row if ANY column has a missing value, basically ye overall saray columns ko dekh k kisi bhi column
# main koi missing value milegi ise to ye usay remove krdega
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_area  Sepal.Area  Petal.Size
# 0         17.85       17.85         1.6
# 1         14.70       14.70         1.6
# ...

# %%
df.dropna(subset=["Sepal.Length"])
# agar hmen sirf ek hi column ko target krna ho k sirf agar us column main missing value ae to remove kre us row ko baki kisi bhi column
# main missig value ho usko ignore krde
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_area  Sepal.Area  Petal.Size
# 0         17.85       17.85         1.6
# 1         14.70       14.70         1.6
# ...

# %% [markdown]
# Sorting

# %%
df.sort_values("Sepal.Length")
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 13            4.3          3.0           1.1          0.1     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
#      Sepal_area  Sepal.Area  Petal.Size
# 13        12.90       12.90         1.2
# 8         12.76       12.76         1.6
# ...

# %% [markdown]
# Sorting (Descending)

# %%
df.sort_values("Sepal.Length", ascending=False)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 131           7.9          3.8           6.4          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
#      Sepal_area  Sepal.Area  Petal.Size
# 131       30.02       30.02         8.4
# 122       21.56       21.56         8.7
# ...

# %% [markdown]
# Update Value - loc[row, column]

# %%
df.loc[0, "Sepal.Length"] = 10
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0            10.0          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_area  Sepal.Area  Petal.Size
# 0         17.85       17.85         1.6
# 1         14.70       14.70         1.6
# ...

# %% [markdown]
# Duplicates - In every column it compares from the previous rows to check if the value is repeated in th column

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %% [markdown]
# Number of duplicated files

# %%
df.duplicated().value_counts()
# Out:
# False    147
# True       3
# Name: count, dtype: int64

# %% [markdown]
# Remove Duplicates

# %%
df.drop_duplicates()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0            10.0          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Sepal_area  Sepal.Area  Petal.Size
# 0         17.85       17.85         1.6
# 1         14.70       14.70         1.6
# ...

# %% [markdown]
# Show duplicate rows

# %%
df[df.duplicated()]
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 34            4.9          3.1           1.5          0.1     setosa
# 37            4.9          3.1           1.5          0.1     setosa
# 142           5.8          2.7           5.1          1.9  virginica
#
#      Sepal_area  Sepal.Area  Petal.Size
# 34        15.19       15.19         1.6
# 37        15.19       15.19         1.6
# 142       15.66       15.66         7.0

# %% [markdown]
# Row difference

# %%
print("Before:", df.shape)
df = df.drop_duplicates()
print("After", df.shape)
# Out:
# Before: (150, 8)
# After (147, 8)

# %% [markdown]
# # **Practice 5**

# %% [markdown]
# Show first 10 rows

# %%
df.head(10)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species  Sepal_area  \
# 0          10.0          3.5           1.4          0.2  setosa       17.85
# 1           4.9          3.0           1.4          0.2  setosa       14.70
# 2           4.7          3.2           1.3          0.2  setosa       15.04
# 3           4.6          3.1           1.5          0.2  setosa       14.26
# 4           5.0          3.6           1.4          0.2  setosa       18.00
# 5           5.4          3.9           1.7          0.4  setosa       21.06
# 6           4.6          3.4           1.4          0.3  setosa       15.64
# 7           5.0          3.4           1.5          0.2  setosa       17.00
# 8           4.4          2.9           1.4          0.2  setosa       12.76
# 9           4.9          3.1           1.5          0.1  setosa       15.19
#
#    Sepal.Area  Petal.Size
# 0       17.85         1.6
# 1       14.70         1.6
# 2       15.04         1.5
# ...

# %% [markdown]
# show petal_length column

# %%
df['Petal.Length']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal.Length, Length: 147, dtype: float64

# %% [markdown]
# Filter rows where spices = "versicolor'

# %%
df[df['Species'] == "versicolor"]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species  \
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %% [markdown]
# Create petal_area column

# %%
df['petal_area'] = df['Petal.Length'] * df['Petal.Width']
df
# Out:
# /tmp/ipython-input-235/380168728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['petal_area'] = df['Petal.Length'] * df['Petal.Width']
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0            10.0          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# ...

# %% [markdown]
# Sort by petal_width descending

# %%
df.sort_values("Petal.Width", ascending=False)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 100           6.3          3.3           6.0          2.5  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# ..            ...          ...           ...          ...        ...
# 39            5.1          3.4           1.5          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 32            5.2          4.1           1.5          0.1     setosa
#
#      Sepal_area  Sepal.Area  Petal.Size  petal_area
# 100       20.79       20.79         8.5       15.00
# ...

# %% [markdown]
# Show average sepal_length

# %%
df['Sepal.Length'].mean()
# Out:
# np.float64(5.889795918367347)

# %% [markdown]
# # **Group by and Aggregation**

# %% [markdown]
# groupby

# %%
df.groupby("Species").mean()
# Out:
#             Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Sepal_area  \
# Species
# setosa          5.112500     3.431250      1.462500     0.250000   17.292917
# versicolor      5.936000     2.770000      4.260000     1.326000   16.526200
# virginica       6.604082     2.979592      5.561224     2.028571   19.766735
#
#             Sepal.Area  Petal.Size  petal_area
# Species
# setosa       17.292917    1.712500    0.371667
# versicolor   16.526200    5.586000    5.720400
# virginica    19.766735    7.589796   11.328980

# %% [markdown]
# Aggregation

# %%
df.groupby("Species").agg(["mean", "max", "min"])
# Out:
#            Sepal.Length            Sepal.Width           Petal.Length       \
#                    mean   max  min        mean  max  min         mean  max
# Species
# setosa         5.112500  10.0  4.3    3.431250  4.4  2.3     1.462500  1.9
# versicolor     5.936000   7.0  4.9    2.770000  3.4  2.0     4.260000  5.1
# virginica      6.604082   7.9  4.9    2.979592  3.8  2.2     5.561224  6.9
#
#                 Petal.Width  ... Sepal_area Sepal.Area                \
#             min        mean  ...        min       mean    max    min
# Species                      ...
# setosa      1.0    0.250000  ...      10.35  17.292917  25.08  10.35
# versicolor  3.0    1.326000  ...      10.00  16.526200  22.40  10.00
# virginica   4.5    2.028571  ...      12.25  19.766735  30.02  12.25
#
#            Petal.Size           petal_area
#                  mean  max  min       mean    max   min
# Species
# setosa       1.712500  2.3  1.2   0.371667   0.96  0.11
# ...

# %% [markdown]
# Count Values - Show the count

# %%
df['Species'].value_counts()
# Out:
# Species
# versicolor    50
# virginica     49
# setosa        48
# Name: count, dtype: int64

# %% [markdown]
# # **Pivot Tables**

# %%
pd.pivot_table(df,
               values = "Sepal.Length",
               index = "Species",
               aggfunc = "mean")
# Out:
#             Sepal.Length
# Species
# setosa          5.112500
# versicolor      5.936000
# virginica       6.604082

# %%
pd.pivot_table(df,
               values = "Sepal.Length",
               index = "Species",
               aggfunc = ["mean", "nunique"])
# Out:
#                    mean      nunique
#            Sepal.Length Sepal.Length
# Species
# setosa         5.112500           16
# versicolor     5.936000           21
# virginica      6.604082           21
