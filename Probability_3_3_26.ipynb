# %% [markdown]
# <a href="https://colab.research.google.com/github/s-rafia/Samsung-Innovation-Campus-AI-Training/blob/main/Probability_3_3_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Discrete probability distribution**

# %%
import scipy.stats as st
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# **1.1 Binomial:**

# %%
# Sample size and the p parameter

n=10
p=0.5  # 50% chance of one outcome, this example is for coin toss, if it were for dice roll p will be 1/6

# %%
# Probability distribution at x = 5
st.binom.pmf(5, n, p)
# Out:
# np.float64(0.24609375000000003)

# %% [markdown]
# ###  1. Hypothesis Test of the Means:

# %% [markdown]
# #### 1.1. One sample t-test:

# %%
import numpy as np
import scipy.stats as st

# %%
n = 10
mu = 3
sigma = 2
np.random.seed(1234)
x = np.random.randn(n)*sigma + mu

# %% [markdown]
# **Two tail test:**

# %%
mu_0 = 0
st.ttest_1samp(x, mu_0)
# Out:
# TtestResult(statistic=np.float64(3.8682023385794677), pvalue=np.float64(0.0037991794351627216), df=np.int64(9))

# %%
mu_0 = 0
x_mean = x.mean()
SEM = x.std(ddof=1)/np.sqrt(n)
p_value = (1-st.t.cdf((x_mean-mu_0)/SEM,df=n-1))*2
p_value
# Out:
# np.float64(0.003799179435162836)

# %%
mu_0 = 1
p_value = (1-st.t.cdf((x_mean-mu_0)/SEM,df=n-1))*2
p_value
# Out:
# np.float64(0.03722962101247096)

# %%
mu_0 = 2
p_value = (1-st.t.cdf((x_mean-mu_0)/SEM,df=n-1))*2
p_value
# Out:
# np.float64(0.3360674694425527)

# %% [markdown]
# **Right tail test:**

# %%
mu_0 = 0
p_value = (1-st.t.cdf((x_mean-mu_0)/SEM,df=n-1))
p_value
# Out:
# np.float64(0.001899589717581418)

# %%
mu_0 = 1
p_value = (1-st.t.cdf((x_mean-mu_0)/SEM,df=n-1))
p_value
# Out:
# np.float64(0.01861481050623548)

# %%
mu_0 = 2
p_value = (1-st.t.cdf((x_mean-mu_0)/SEM,df=n-1))
p_value
# Out:
# np.float64(0.16803373472127636)

# %% [markdown]
# **Left tail test:**

# %%
mu_0 = 0
p_value = st.t.cdf((x_mean-mu_0)/SEM,df=n-1)
p_value
# Out:
# np.float64(0.9981004102824186)

# %%
mu_0 = 1
p_value = st.t.cdf((x_mean-mu_0)/SEM,df=n-1)
p_value
# Out:
# np.float64(0.9813851894937645)

# %%
mu_0 = 2
p_value = st.t.cdf((x_mean-mu_0)/SEM,df=n-1)
p_value
# Out:
# np.float64(0.8319662652787236)
